# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uomna/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Structured Content Archetype Clustering
#
# I chose this lane because it focuses on analyzing and grouping content types into meaningful clusters based on performance and engagement features. This helps identify patterns behind successful content and supports better publishing and recommendation strategies.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision:
# My work improves the decision of how to categorize and prioritize different types of website content based on their performance and engagement patterns.
#
# Action:
# Content strategists and SEO specialists act on this decision. They use the clustering results to decide which content archetypes to refresh, replicate, or promote in order to maximize engagement and visibility.
#
# Cost of a wrong recommendation:
# If the clustering is inaccurate, content may be misclassified. This can lead to poor optimization choices, wasted resources, and reduced engagement. In the worst case, it could harm overall site performance and visibility in search results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# To support my lane choice, I explored the starter dataset and found several key numbers that show why clustering content is valuable.
# The dataset includes around 27,532 content items with 44 features. For example, the average word count is about 3,100 and the mean impressions over 90 days are around 5,200.
# These numbers indicate strong variation in content performance, making it suitable for identifying distinct content archetypes.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/uomna/flyrank-ml/refs/heads/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

print(df.shape)      # shows number of rows and columns
print(df.head())     # shows first few rows
print(df.describe()) # shows basic statistics
# Out:
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work can identify patterns and group content types based on observed performance metrics such as impressions, clicks, and engagement rate.
# It can provide directional insights and decision support for improving content strategy.
# However, it cannot prove causation or predict how Google ranks content.
# The results will show correlations and useful groupings, not causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
